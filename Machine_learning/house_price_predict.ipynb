# %% [markdown]
# <a href="https://colab.research.google.com/github/rezakhanahmadi342341/projects/blob/main/house_price_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline

# %%
data = pd.read_csv('/content/housing.csv')

# %%
ocean_proximity = data['ocean_proximity']
data = data.drop(['ocean_proximity'], axis=1)
x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %% [markdown]
# #**Imputer**

# %%
emput = SimpleImputer(strategy='median')
data = emput.fit_transform(x)
empute_df = pd.DataFrame(data)
empute_df.columns = x.columns
x = empute_df

# %% [markdown]
# #**scale** **Data**

# %%
scale = StandardScaler()
x = pd.DataFrame(scale.fit_transform(x), columns=x.columns)
x.shape
scale_y = StandardScaler()
y = pd.DataFrame(scale_y.fit_transform(y.values.reshape(-1,1)), columns=['median_house_value'])
y
# Out:
#        median_house_value
# 0                2.129631
# 1                1.314156
# 2                1.258693
# 3                1.165100
# 4                1.172900
# ...                   ...
# 20635           -1.115804
# 20636           -1.124470
# 20637           -0.992746
# 20638           -1.058608
# 20639           -1.017878
#
# [20640 rows x 1 columns]

# %% [markdown]
# # **OneHotEncoder**

# %%
one_hot = OneHotEncoder(sparse_output=False)
one_hoted = one_hot.fit_transform(ocean_proximity.values.reshape(-1,1))
ocian_df = pd.DataFrame(one_hoted)
ocian_df.columns = ['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']
x = pd.concat([x, ocian_df], axis=1)
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -1.327835  1.052548            0.982143    -0.804819       -0.972476
# 1      -1.322844  1.043185           -0.607019     2.045890        1.357143
# 2      -1.332827  1.038503            1.856182    -0.535746       -0.827024
# 3      -1.337818  1.038503            1.856182    -0.624215       -0.719723
# 4      -1.337818  1.038503            1.856182    -0.462404       -0.612423
# ...          ...       ...                 ...          ...             ...
# 20635  -0.758826  1.801647           -0.289187    -0.444985       -0.388283
# 20636  -0.818722  1.806329           -0.845393    -0.888704       -0.922403
# 20637  -0.823713  1.778237           -0.924851    -0.174995       -0.123608
# 20638  -0.873626  1.778237           -0.845393    -0.355600       -0.304827
# 20639  -0.833696  1.750146           -1.004309     0.068408        0.188757
#
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
x = pd.DataFrame(pca.fit_transform(x))
x
# Out:
#               0         1         2         3         4         5         6  \
# 0     -2.116265  1.429257  2.177526  1.408854 -0.353114  0.197623  0.138651
# 1      2.917952  2.002815  2.252761  0.914876 -0.279609  0.398755 -0.369813
# 2     -1.993166  1.500265  1.354692  2.067478 -0.496646  0.121378  0.068724
# 3     -1.942975  1.556825  0.544701  1.826510 -0.324375  0.186960  0.025565
# 4     -1.801224  1.632632 -0.322936  1.573450 -0.189185  0.259712 -0.128073
# ...         ...       ...       ...       ...       ...       ...       ...
# 20635 -1.060857  1.843803 -0.883051 -1.089862 -0.261039 -0.354527 -0.134201
# 20636 -1.877595  1.740057 -0.095745 -1.592488 -0.170381 -0.315585 -0.034646
# 20637 -0.461731  1.923451 -0.644180 -1.525673 -0.133616 -0.253555 -0.209290
# 20638 -0.873860  1.906855 -0.536412 -1.499791 -0.145871 -0.243821 -0.244579
# 20639  0.127240  1.955939 -0.360292 -1.376356 -0.183789 -0.279315 -0.130985
#
#               7         8         9
# ...

# %% [markdown]
# #train a mudel

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3, shuffle=True)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
score = model.score(x_test, y_test)
score
# Out:
# 0.6529819540344384

# %%
pre = model.predict(x_test)

# %%
mse = mean_squared_error(pre, y_test)
mse = np.sqrt(mse)
mse
# Out:
# 0.587101593249776

# %%
linear_models = [
    LinearRegression(),
    Ridge(),
    Lasso(),
    ElasticNet(),
    make_pipeline(PolynomialFeatures(degree=2), LinearRegression()),  # Polynomial Regression
    SVR()
]

# %%
def models (models, x_train, y_train, x_test, y_test):
  for model in models:
    model.fit(x_train, y_train)
    score = model.score(x_test, y_test)
    print(f"{model} score: {score}")
    print('-' * 100)

# %%
models(linear_models, x_train, y_train, x_test, y_test)
# Out:
# LinearRegression() score: 0.6529819540344384
# ----------------------------------------------------------------------------------------------------
# Ridge() score: 0.6529772310643136
# ----------------------------------------------------------------------------------------------------
# Lasso() score: -3.199064096448545e-05
# ----------------------------------------------------------------------------------------------------
# ElasticNet() score: 0.08864035645288337
# ----------------------------------------------------------------------------------------------------
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())]) score: 0.7199981780690726
# ----------------------------------------------------------------------------------------------------
# SVR() score: 0.7691795854513512
# ----------------------------------------------------------------------------------------------------
